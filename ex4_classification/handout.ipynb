# %% [markdown]
# # Exercise 4: Image Classification
#
# **Deadline: 23 December 2022, 11:59 PM**
#
# **Covered Topics: Lecture 9-10**
#
#
# Given an input RGB image, you should train a neural network which outputs the class label the image belongs to.
# There are six class labels in our dataset: "buildings", "forests", "mountains", "glacier", "sea", and "street".
# In order to design and train your network, we provide a training set and validation set along with class labels for every image.
# As you are already familiar, we separate the dataset into three splits: training, validation, and testing.
# The train set has 6K images (1K per class), and the val and test sets each have 1.2K images (200 per class).
#
# An overview of the desired pipeline is shown in Figure.
#
#
# ![](https://docs.google.com/drawings/d/e/2PACX-1vRynZcZ1jfCu1GAsY9Hww68kr3iGaHj5XKeQptkF9lRysFpMtbbs4TZZaklAemoZJbMR-LUQnVkkI0b/pub?w=680&h=483 "Title")
#
#
# This exercise acts as a gentle introduction to [PyTorch](https://pytorch.org/), one of the most popular deep learning frameworks.
# We provide a majority of the code to get you started and familiarized with the framework.
# Running through all the cells will give you a simple linear network that can achieve the baseline performance.
# To pass, you will need to modify the given implementation and train a network that can achieve better performance.
#
# **Evaluation Criteria**
#
# Your algorithm will be evaluated using classification accuracy, which is the proportion of images with the correct predicted label.
# The final EvaluationScore is obtained as the classification accuracy over all test samples.
#
# **Passing requirement**
#
# Your algorithm will be evaluated on a test set. In order to pass the exercise, you need to obtain an EvaluationScore of **greater than $70.0$** on the test set.
#
# Follow the steps in the rest of the notebook to generate the submission. The evaluation server for the exercise is at https://codalab.lisn.upsaclay.fr/competitions/8751.

# %% [markdown]
# ## Initialize the environment and load data
# Import the necessary libraries. Note that you are **NOT** allowed to use any additional libraries

# %%
# These two lines ensure that we always import the latest version of a package, in case it has been modified.
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
from matplotlib import pyplot as plt
import csv
import cv2
import os
import numpy as np
import random
import shutil

from google.colab import drive
drive.mount('/content/drive')

import sys

import torch
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **TODO:** Set the path in Google drive where you uploaded the handout, e.g. My Drive/iacv/ex4

# %%
iacv_path = 'MyDrive/ETH Computer Vision/ex4_classification' # TODO set this

env_path = f'/content/drive/{iacv_path}'
# Add the handout folder to python paths
if env_path not in sys.path:
    sys.path.append(env_path)

# %% [markdown]
# Define the plotting function to visualize the images and the network predictions.

# %%
# class labels. This provides the mapping from the integer label for an image to
# a descriptive name
classes = ["Buildings", "Forest", "Mountains", "Glacier", "Sea", "Street"]

# function to show image
def show_images(ims, gt_labels, pred_labels=None):
    fig, ax = plt.subplots(1, len(ims), figsize=(20, 20))
    for id in range(len(ims)):
        im = ims[id]
        im = im / 2 + 0.5     # unnormalize
        im_np = im.numpy()

        ax[id].imshow(np.transpose(im_np, (1, 2, 0)))

        if pred_labels is None:
            im_title = f'GT: {classes[gt_labels[id]]}'
        else:
            im_title = f'GT: {classes[gt_labels[id]]}   Pred: {classes[pred_labels[id]]}'
        ax[id].set_title(im_title)
    plt.show()

# %% [markdown]
# ## Overview
#
# In general, training any deep learning models consists of the following components
#
#
# *   **Dataset:** The data on which the model is trained. This could be e.g. large number of images, videos, text documents etc.
# *   **Model:** The network architecture we want to train. A significant part of developing deep learning solutions involves designing right architecture for a given problem.
# *   **Cost Function:** The criteria which is minimized over our dataaset to train the network, e.g. Cross-entropy loss, Mean-squared error.
# *   **Optimizer:** The optimizer updates the model parameters to minimize the cost function. The most common example is Stochastic Gradient Descent. One also has to determine hyperparameters such as the learning rate, number of optimization iterations etc.
#
# As discussed in the lectures, the deep networks are trained using *mini-batches*, which are a set of training images (commonly between 8-128). Furthermore, data augmentation strategies (e.g. rotating an image) are commonly used to 'transform' the training images first, before passing it to a network. Thus, the data loading step itself can be broken down into following sub-steps,
# 1.   Load an image from the dataset. The images are randomly loaded from the dataset during training to avoid any bias.
# 2.   Apply necessary pre-processing to the image, e.g. remove mean, convert datatype to `float` etc.
# 3.   Apply desired data augmentations to the image, e.g. rotate an image, extract a random crop from the image.
# 4. Group a number of processed images to form a 'training batch'. This batch is then passed through the network to obtain predictions and compute loss.
#
#
#
#
# We will use the [PyTorch](https://pytorch.org/) deep learning framework to implement each of these components. Follow through the next cells to check the implementation.

# %% [markdown]
# ## Step 1: Data Loading
#
# We first take a look at how to define the datasets and data loading procedures in PyTorch.
#
# To do so, we need to create a PyTorch Dataset and DataLoader.
# The PyTorch Dataset handles loading the actual images and labels from file as well as applying any transformations on the loaded image. To define your own Dataset, you need to subclass the `torch.utils.data.Dataset` class and implement three functions:
#
# 1. `__init__`: Initialize the dataset.
# 2. `__len__`: Returns the number of samples in the dataset.
# 3. `__getitem__`: Given a specific index, load the corresponding image and labels, apply necessary transformations, and return them.
#
# We have implemented a dataset class for our task here. Please take a close look at how it is done.

# %%
import csv
import h5py
from PIL import Image
from io import BytesIO

import torchvision
from torch.utils.data import Dataset, DataLoader


def load_image(hdf5_file, im_path):
    """Helper function for loading images stored in a HDF5 file.
    
    HDF5 enables a compact way to store images, without needing to store each
    image as a separate file.
    """
    return np.array(
        Image.open(BytesIO(bytearray(bytes(hdf5_file[im_path][()]))))
    )


class ImageDataset(Dataset):
    """PyTorch Dataset for loading our data.
    
    annotations_file specifies the file that stores the classification labels.
    img_file specifies the file where all images are stored.
    transform specifies the transformations to apply to the loaded image.
    """

    def __init__(self, annotations_file, img_file, transform=None):
        """Initialize dataset."""
        with open(annotations_file) as fp:
            self.img_labels = [line.strip().split(',') for line in fp.readlines()]
        self.img_file = h5py.File(img_file, mode="r")
        self.transform = transform

    def __len__(self):
        """Return length of dataset."""
        return len(self.img_labels)

    def __getitem__(self, idx):
        """Get image and labels at the given index."""
        image = load_image(self.img_file, self.img_labels[idx][0])
        if self.transform:
            image = self.transform(image)
        if len(self.img_labels[idx]) > 1:
            label = int(self.img_labels[idx][1])
            return image, label
        return image

# %% [markdown]
# Note that the PyTorch Dataset only deals with loading a single image at a time.
# The data sampling logic for loading multiple images is handled by the PyTorch DataLoader, which takes the Dataset as input and defines the logic for how to iterate over the entire dataset. To create the DataLoader, you need to use `torch.utils.data.DataLoader`, which has the following arguments:
#
# - `dataset`: A PyTorch Dataset.
# - `batch_size`: Number of images to load at a time.
# - `shuffle`: Whether to shuffle the dataset before loading the images. Usually, you will use shuffling during training and not during testing.
# - `num_workers`: Number of subprocesses to use for data loading.
# - ... and many more. You can find the full list [here](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader).
#
#
# The following function returns DataLoaders for each of our training, validation, and test datasets.

# %%
def get_dataloaders(batch_size, transform_train, transform_val):
    """ Returns PyTorch DataLoaders for training, validation, and test sets
     
    batch_size: Specifies the number of images in each batch.
    transform_train: Denotes the transformations (i.e. preprocessing and data
                     augmentation) applied to each training image
    transform_val: Denotes the transformations (i.e. preprocessing) applied to \
                   each validation and test image. Note that we do not want to 
                   apply data augmentations on val and test images, since it is
                   a regularization technique only used in training
    """

    # create datasets (train, validation, and test)
    train_dataset = ImageDataset(
        f"{env_path}/data/train.csv", f"{env_path}/data/train.hdf5", transform=transform_train
    )
    val_dataset = ImageDataset(
        f"{env_path}/data/val.csv", f"{env_path}/data/val.hdf5", transform=transform_val
    )
    test_dataset = ImageDataset(
        f"{env_path}/data/test.csv", f"{env_path}/data/test.hdf5", transform=transform_val
    )

    # create dataloaders (train, validation, and test)
    num_workers = 0  # number of subprocesses to use. Only impacts training speed,
                     # and not classification accuracy
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers
    )
    val_loader = DataLoader(
        val_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers
    )
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
    
    return train_loader, val_loader, test_loader

# %% [markdown]
# Next, we create our data loaders using desired transforms.

# %%
from cnn_network import get_transforms_val, get_transforms_train

batch_size = 8

# Get the transformations (pre-processing, data augmentation) to be applied to each images.
# Note that the transforms have been defined in cnn_network.py file provided to you.
transform_train = get_transforms_train()
transform_val = get_transforms_val()

# Generate our data loaders
train_loader, val_loader, test_loader = get_dataloaders(batch_size, transform_train, transform_val)

# %% [markdown]
# Visualize a few training samples along with the ground truth labels to get an idea of how the images look. You can run this multiple times to check different images

# %%
# get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

show_images(images[:6], labels[:6])

# %% [markdown]
# ## Step 2: Define the Network
#
# After we've set up the data, we now need to define the network we will use to perform image classification.
#
# To do so, we need to create a PyTorch network.
# To define your own PyTorch network, you need to subclass the `torch.nn.Module` class and implement two functions:
#
# 1. `__init__`: Initialize the network, defining all the layers in the network to use.
# 2. `forward`: Defines the forward pass of the network, which takes an image as input and outputs classification scores for each class.
#
# As you will notice, we only have to define the forward pass of the network but not the backward pass (backpropagation). This is because PyTorch handles computing gradients for each operation for you ([autograd](https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html)), so you don't have to worry about it at all!
#
# We've implemented a very simple CNN for you already in `cnn_network.py` with a single convolutional layer, pooling layer, and fully-connected layer. You can run this cell to see the network architecture as well as test the forward pass of the network.
#
# **Important:** Don't forget to import the `cnn_network.py` file every time you modify it, otherwise your latest changes won't be loaded.

# %%
from cnn_network import CNN

cnn_network = CNN()  # create CNN model

print("CNN Architecture:")
print(cnn_network)

print("")
print("Testing network input / output.")
test_input = torch.zeros(1, 3, 50, 50)  # batch size X 3 (RGB) X width X height
print(f"Input shape: {test_input.shape}")
test_output = cnn_network(test_input)  # batch size X # classes
print(f"Output shape: {test_output.shape}")

assert tuple(test_output.shape) == (1, 6), "Output shape should be [1, 6]"
# Out:
# CNN Architecture:
# CNN(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=150, out_features=6, bias=True)
# )
#
# Testing network input / output.
# Input shape: torch.Size([1, 3, 50, 50])
# Output shape: torch.Size([1, 6])

# %% [markdown]
# ## Step 3: Define the cost function and the optimizer
#
# Next we define the cost function and the optimizer to be used for training.
#
# For the image classification task, the most commonly use loss function is the Cross-Entropy loss, which we will use here. However, feel free to play around with other losses you can think of.
#
# We will use the Stochastic-Gradient descent optimizer. The optimizer contains two hyperparameters, namely the learning rate and the momentum. You are free to test other optimizers. Note that PyTorch gives implementations of commonly used optimizers such as SGD, Adam, etc.
#
# Please check the `cnn_network.py` file to see how these components are defined.

# %%
from cnn_network import get_loss_function, get_optimizer

criterion = get_loss_function()  # get loss function
optimizer = get_optimizer(cnn_network, lr=0.001, momentum=0.9)  # get optimizer

# %% [markdown]
# ## Step 4: Train the Network
#
# Now that we've defined both the data and the network, it's time to train our network on the data.
#
# To do so, we simply just iterate over each batch of data, compute the network loss, then optimize the network parameters with backpropagation. See the code below for details on the right way to do this in PyTorch.
#
# Run this cell to train the network.
# This may take some time.
# You should see the training loss go down in the initial iterations then plateau.
#
# **Note:** We reinitialize the network, and load dataset, optimizer, loss function etc again here so that it is convenient to modify them in a single place.

# %%
from cnn_network import get_transforms_val, get_transforms_train, CNN, get_loss_function, get_optimizer

# *********************************************************** #
# set all training parameters. You can play around with these
# *********************************************************** #

batch_size = 32          # Number of images in each batch
learning_rate = 0.001    # Learning rate in the optimizer
momentum = 0.9           # Momentum in SGD
num_epochs = 200           # Number of passes over the entire dataset
print_every_iters = 45  # Print training loss every X mini-batches


# *********************************************************** #
# Initialize all the training components, e.g. model, cost function
# *********************************************************** #



# Get transforms
transform_train = get_transforms_train()
transform_val = get_transforms_val()

# Generate our data loaders
train_loader, val_loader, test_loader = get_dataloaders(batch_size, transform_train, transform_val)

# create CNN model
cnn_network = CNN()  

# Get optimizer and loss functions
criterion = get_loss_function() 
optimizer = get_optimizer(cnn_network, lr=learning_rate, momentum=momentum) 





# *********************************************************** #
# The main training loop. You dont need to change this
# *********************************************************** #
training_loss_per_epoch = []
val_loss_per_epoch = []
for epoch in range(num_epochs):  # loop over the dataset multiple times
    # First we loop over training dataset
    running_loss = 0.0

    # Set network to train mode before training
    cnn_network.train()
    for i, data in enumerate(train_loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()  # zero the gradients from previous iteration

        # forward + backward + optimize
        outputs = cnn_network(inputs)  # forward pass to obtain network outputs
        loss = criterion(outputs, labels)  # compute loss with respect to labels
        loss.backward()  # compute gradients with backpropagation (autograd)
        optimizer.step()  # optimize network parameters

        # print statistics
        running_loss += loss.item()
        if (i + 1) % print_every_iters == 0:
            print(
                f'[Epoch: {epoch + 1} / {num_epochs},'
                f' Iter: {i + 1:5d} / {len(train_loader)}]'
                f' Training loss: {running_loss / (i + 1):.3f}'
            )
    
    mean_loss = running_loss / len(train_loader)
    training_loss_per_epoch.append(mean_loss)

    # Next we loop over validation dataset
    running_loss = 0.0

    # Set network to eval mode before validation
    cnn_network.eval()
    for i, data in enumerate(val_loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # on validation dataset, we only do forward, without computing gradients
        with torch.no_grad():
            outputs = cnn_network(inputs)  # forward pass to obtain network outputs
            loss = criterion(outputs, labels)  # compute loss with respect to labels
        
        # print statistics
        running_loss += loss.item()

    mean_loss = running_loss / len(val_loader)
    val_loss_per_epoch.append(mean_loss)

    print(
        f'[Epoch: {epoch + 1} / {num_epochs}]'
        f' Validation loss: {mean_loss:.3f}'
    )

print('Finished Training')

# Plot the training curves
plt.figure()
plt.plot(np.array(training_loss_per_epoch))
plt.plot(np.array(val_loss_per_epoch))
plt.legend(['Training loss', 'Val loss'])
plt.xlabel('Epoch')
plt.show()
plt.close()
# Out:
# [Epoch: 1 / 200, Iter:    45 / 188] Training loss: 1.792
# [Epoch: 1 / 200, Iter:    90 / 188] Training loss: 1.792
# [Epoch: 1 / 200, Iter:   135 / 188] Training loss: 1.791
# [Epoch: 1 / 200, Iter:   180 / 188] Training loss: 1.791
# [Epoch: 1 / 200] Validation loss: 1.788
# [Epoch: 2 / 200, Iter:    45 / 188] Training loss: 1.788
# [Epoch: 2 / 200, Iter:    90 / 188] Training loss: 1.787
# [Epoch: 2 / 200, Iter:   135 / 188] Training loss: 1.787
# [Epoch: 2 / 200, Iter:   180 / 188] Training loss: 1.786
# [Epoch: 2 / 200] Validation loss: 1.783
# [Epoch: 3 / 200, Iter:    45 / 188] Training loss: 1.783
# [Epoch: 3 / 200, Iter:    90 / 188] Training loss: 1.783
# [Epoch: 3 / 200, Iter:   135 / 188] Training loss: 1.783
# [Epoch: 3 / 200, Iter:   180 / 188] Training loss: 1.781
# [Epoch: 3 / 200] Validation loss: 1.773
# [Epoch: 4 / 200, Iter:    45 / 188] Training loss: 1.772
# [Epoch: 4 / 200, Iter:    90 / 188] Training loss: 1.770
# [Epoch: 4 / 200, Iter:   135 / 188] Training loss: 1.767
# [Epoch: 4 / 200, Iter:   180 / 188] Training loss: 1.763
# [Epoch: 4 / 200] Validation loss: 1.744
# [Epoch: 5 / 200, Iter:    45 / 188] Training loss: 1.740
# [Epoch: 5 / 200, Iter:    90 / 188] Training loss: 1.737
# [Epoch: 5 / 200, Iter:   135 / 188] Training loss: 1.732
# [Epoch: 5 / 200, Iter:   180 / 188] Training loss: 1.724
# [Epoch: 5 / 200] Validation loss: 1.691
# [Epoch: 6 / 200, Iter:    45 / 188] Training loss: 1.691
# [Epoch: 6 / 200, Iter:    90 / 188] Training loss: 1.690
# [Epoch: 6 / 200, Iter:   135 / 188] Training loss: 1.683
# [Epoch: 6 / 200, Iter:   180 / 188] Training loss: 1.674
# [Epoch: 6 / 200] Validation loss: 1.644
# [Epoch: 7 / 200, Iter:    45 / 188] Training loss: 1.652
# [Epoch: 7 / 200, Iter:    90 / 188] Training loss: 1.642
# [Epoch: 7 / 200, Iter:   135 / 188] Training loss: 1.639
# [Epoch: 7 / 200, Iter:   180 / 188] Training loss: 1.628
# [Epoch: 7 / 200] Validation loss: 1.587
# [Epoch: 8 / 200, Iter:    45 / 188] Training loss: 1.601
# [Epoch: 8 / 200, Iter:    90 / 188] Training loss: 1.582
# [Epoch: 8 / 200, Iter:   135 / 188] Training loss: 1.565
# [Epoch: 8 / 200, Iter:   180 / 188] Training loss: 1.551
# [Epoch: 8 / 200] Validation loss: 1.461
# [Epoch: 9 / 200, Iter:    45 / 188] Training loss: 1.479
# [Epoch: 9 / 200, Iter:    90 / 188] Training loss: 1.473
# [Epoch: 9 / 200, Iter:   135 / 188] Training loss: 1.458
# [Epoch: 9 / 200, Iter:   180 / 188] Training loss: 1.458
# [Epoch: 9 / 200] Validation loss: 1.387
# [Epoch: 10 / 200, Iter:    45 / 188] Training loss: 1.455
# [Epoch: 10 / 200, Iter:    90 / 188] Training loss: 1.419
# [Epoch: 10 / 200, Iter:   135 / 188] Training loss: 1.405
# [Epoch: 10 / 200, Iter:   180 / 188] Training loss: 1.397
# [Epoch: 10 / 200] Validation loss: 1.337
# [Epoch: 11 / 200, Iter:    45 / 188] Training loss: 1.355
# [Epoch: 11 / 200, Iter:    90 / 188] Training loss: 1.363
# [Epoch: 11 / 200, Iter:   135 / 188] Training loss: 1.362
# [Epoch: 11 / 200, Iter:   180 / 188] Training loss: 1.349
# [Epoch: 11 / 200] Validation loss: 1.281
# [Epoch: 12 / 200, Iter:    45 / 188] Training loss: 1.338
# [Epoch: 12 / 200, Iter:    90 / 188] Training loss: 1.340
# [Epoch: 12 / 200, Iter:   135 / 188] Training loss: 1.326
# [Epoch: 12 / 200, Iter:   180 / 188] Training loss: 1.320
# [Epoch: 12 / 200] Validation loss: 1.261
# [Epoch: 13 / 200, Iter:    45 / 188] Training loss: 1.284
# [Epoch: 13 / 200, Iter:    90 / 188] Training loss: 1.306
# [Epoch: 13 / 200, Iter:   135 / 188] Training loss: 1.295
# [Epoch: 13 / 200, Iter:   180 / 188] Training loss: 1.287
# [Epoch: 13 / 200] Validation loss: 1.244
# [Epoch: 14 / 200, Iter:    45 / 188] Training loss: 1.270
# [Epoch: 14 / 200, Iter:    90 / 188] Training loss: 1.278
# [Epoch: 14 / 200, Iter:   135 / 188] Training loss: 1.272
# [Epoch: 14 / 200, Iter:   180 / 188] Training loss: 1.251
# [Epoch: 14 / 200] Validation loss: 1.119
# [Epoch: 15 / 200, Iter:    45 / 188] Training loss: 1.178
# [Epoch: 15 / 200, Iter:    90 / 188] Training loss: 1.149
# [Epoch: 15 / 200, Iter:   135 / 188] Training loss: 1.161
# [Epoch: 15 / 200, Iter:   180 / 188] Training loss: 1.150
# [Epoch: 15 / 200] Validation loss: 1.048
# [Epoch: 16 / 200, Iter:    45 / 188] Training loss: 1.094
# [Epoch: 16 / 200, Iter:    90 / 188] Training loss: 1.101
# [Epoch: 16 / 200, Iter:   135 / 188] Training loss: 1.098
# [Epoch: 16 / 200, Iter:   180 / 188] Training loss: 1.098
# [Epoch: 16 / 200] Validation loss: 1.020
# [Epoch: 17 / 200, Iter:    45 / 188] Training loss: 1.079
# [Epoch: 17 / 200, Iter:    90 / 188] Training loss: 1.104
# [Epoch: 17 / 200, Iter:   135 / 188] Training loss: 1.086
# [Epoch: 17 / 200, Iter:   180 / 188] Training loss: 1.075
# [Epoch: 17 / 200] Validation loss: 1.006
# [Epoch: 18 / 200, Iter:    45 / 188] Training loss: 1.038
# [Epoch: 18 / 200, Iter:    90 / 188] Training loss: 1.052
# [Epoch: 18 / 200, Iter:   135 / 188] Training loss: 1.032
# [Epoch: 18 / 200, Iter:   180 / 188] Training loss: 1.031
# [Epoch: 18 / 200] Validation loss: 0.996
# [Epoch: 19 / 200, Iter:    45 / 188] Training loss: 1.017
# [Epoch: 19 / 200, Iter:    90 / 188] Training loss: 1.026
# [Epoch: 19 / 200, Iter:   135 / 188] Training loss: 1.028
# [Epoch: 19 / 200, Iter:   180 / 188] Training loss: 1.019
# [Epoch: 19 / 200] Validation loss: 0.971
# [Epoch: 20 / 200, Iter:    45 / 188] Training loss: 0.953
# [Epoch: 20 / 200, Iter:    90 / 188] Training loss: 0.983
# [Epoch: 20 / 200, Iter:   135 / 188] Training loss: 0.993
# [Epoch: 20 / 200, Iter:   180 / 188] Training loss: 0.998
# [Epoch: 20 / 200] Validation loss: 0.976
# [Epoch: 21 / 200, Iter:    45 / 188] Training loss: 0.980
# [Epoch: 21 / 200, Iter:    90 / 188] Training loss: 0.990
# [Epoch: 21 / 200, Iter:   135 / 188] Training loss: 0.984
# [Epoch: 21 / 200, Iter:   180 / 188] Training loss: 0.980
# [Epoch: 21 / 200] Validation loss: 0.955
# [Epoch: 22 / 200, Iter:    45 / 188] Training loss: 1.011
# [Epoch: 22 / 200, Iter:    90 / 188] Training loss: 0.982
# [Epoch: 22 / 200, Iter:   135 / 188] Training loss: 0.980
# [Epoch: 22 / 200, Iter:   180 / 188] Training loss: 0.974
# [Epoch: 22 / 200] Validation loss: 0.945
# [Epoch: 23 / 200, Iter:    45 / 188] Training loss: 1.004
# [Epoch: 23 / 200, Iter:    90 / 188] Training loss: 0.981
# [Epoch: 23 / 200, Iter:   135 / 188] Training loss: 0.978
# [Epoch: 23 / 200, Iter:   180 / 188] Training loss: 0.965
# [Epoch: 23 / 200] Validation loss: 0.932
# [Epoch: 24 / 200, Iter:    45 / 188] Training loss: 0.932
# [Epoch: 24 / 200, Iter:    90 / 188] Training loss: 0.962
# [Epoch: 24 / 200, Iter:   135 / 188] Training loss: 0.954
# [Epoch: 24 / 200, Iter:   180 / 188] Training loss: 0.951
# [Epoch: 24 / 200] Validation loss: 0.915
# [Epoch: 25 / 200, Iter:    45 / 188] Training loss: 0.932
# [Epoch: 25 / 200, Iter:    90 / 188] Training loss: 0.927
# [Epoch: 25 / 200, Iter:   135 / 188] Training loss: 0.931
# [Epoch: 25 / 200, Iter:   180 / 188] Training loss: 0.934
# [Epoch: 25 / 200] Validation loss: 0.930
# [Epoch: 26 / 200, Iter:    45 / 188] Training loss: 0.945
# [Epoch: 26 / 200, Iter:    90 / 188] Training loss: 0.942
# [Epoch: 26 / 200, Iter:   135 / 188] Training loss: 0.928
# [Epoch: 26 / 200, Iter:   180 / 188] Training loss: 0.926
# [Epoch: 26 / 200] Validation loss: 0.938
# [Epoch: 27 / 200, Iter:    45 / 188] Training loss: 0.894
# [Epoch: 27 / 200, Iter:    90 / 188] Training loss: 0.900
# [Epoch: 27 / 200, Iter:   135 / 188] Training loss: 0.903
# [Epoch: 27 / 200, Iter:   180 / 188] Training loss: 0.918
# [Epoch: 27 / 200] Validation loss: 0.902
# [Epoch: 28 / 200, Iter:    45 / 188] Training loss: 0.874
# [Epoch: 28 / 200, Iter:    90 / 188] Training loss: 0.931
# [Epoch: 28 / 200, Iter:   135 / 188] Training loss: 0.929
# [Epoch: 28 / 200, Iter:   180 / 188] Training loss: 0.926
# [Epoch: 28 / 200] Validation loss: 0.878
# [Epoch: 29 / 200, Iter:    45 / 188] Training loss: 0.909
# [Epoch: 29 / 200, Iter:    90 / 188] Training loss: 0.896
# [Epoch: 29 / 200, Iter:   135 / 188] Training loss: 0.892
# [Epoch: 29 / 200, Iter:   180 / 188] Training loss: 0.900
# [Epoch: 29 / 200] Validation loss: 0.891
# [Epoch: 30 / 200, Iter:    45 / 188] Training loss: 0.910
# [Epoch: 30 / 200, Iter:    90 / 188] Training loss: 0.877
# [Epoch: 30 / 200, Iter:   135 / 188] Training loss: 0.888
# [Epoch: 30 / 200, Iter:   180 / 188] Training loss: 0.880
# [Epoch: 30 / 200] Validation loss: 0.898
# [Epoch: 31 / 200, Iter:    45 / 188] Training loss: 0.865
# [Epoch: 31 / 200, Iter:    90 / 188] Training loss: 0.871
# [Epoch: 31 / 200, Iter:   135 / 188] Training loss: 0.876
# [Epoch: 31 / 200, Iter:   180 / 188] Training loss: 0.885
# [Epoch: 31 / 200] Validation loss: 0.875
# [Epoch: 32 / 200, Iter:    45 / 188] Training loss: 0.879
# [Epoch: 32 / 200, Iter:    90 / 188] Training loss: 0.863
# [Epoch: 32 / 200, Iter:   135 / 188] Training loss: 0.866
# [Epoch: 32 / 200, Iter:   180 / 188] Training loss: 0.874
# [Epoch: 32 / 200] Validation loss: 0.878
# [Epoch: 33 / 200, Iter:    45 / 188] Training loss: 0.877
# [Epoch: 33 / 200, Iter:    90 / 188] Training loss: 0.873
# [Epoch: 33 / 200, Iter:   135 / 188] Training loss: 0.874
# [Epoch: 33 / 200, Iter:   180 / 188] Training loss: 0.870
# [Epoch: 33 / 200] Validation loss: 0.863
# [Epoch: 34 / 200, Iter:    45 / 188] Training loss: 0.889
# [Epoch: 34 / 200, Iter:    90 / 188] Training loss: 0.869
# [Epoch: 34 / 200, Iter:   135 / 188] Training loss: 0.861
# [Epoch: 34 / 200, Iter:   180 / 188] Training loss: 0.861
# [Epoch: 34 / 200] Validation loss: 0.905
# [Epoch: 35 / 200, Iter:    45 / 188] Training loss: 0.838
# [Epoch: 35 / 200, Iter:    90 / 188] Training loss: 0.840
# [Epoch: 35 / 200, Iter:   135 / 188] Training loss: 0.859
# [Epoch: 35 / 200, Iter:   180 / 188] Training loss: 0.855
# [Epoch: 35 / 200] Validation loss: 0.895
# [Epoch: 36 / 200, Iter:    45 / 188] Training loss: 0.874
# [Epoch: 36 / 200, Iter:    90 / 188] Training loss: 0.877
# [Epoch: 36 / 200, Iter:   135 / 188] Training loss: 0.868
# [Epoch: 36 / 200, Iter:   180 / 188] Training loss: 0.865
# [Epoch: 36 / 200] Validation loss: 0.848
# [Epoch: 37 / 200, Iter:    45 / 188] Training loss: 0.866
# [Epoch: 37 / 200, Iter:    90 / 188] Training loss: 0.874
# [Epoch: 37 / 200, Iter:   135 / 188] Training loss: 0.858
# [Epoch: 37 / 200, Iter:   180 / 188] Training loss: 0.856
# [Epoch: 37 / 200] Validation loss: 0.883
# [Epoch: 38 / 200, Iter:    45 / 188] Training loss: 0.829
# [Epoch: 38 / 200, Iter:    90 / 188] Training loss: 0.848
# [Epoch: 38 / 200, Iter:   135 / 188] Training loss: 0.834
# [Epoch: 38 / 200, Iter:   180 / 188] Training loss: 0.850
# [Epoch: 38 / 200] Validation loss: 0.856
# [Epoch: 39 / 200, Iter:    45 / 188] Training loss: 0.839
# [Epoch: 39 / 200, Iter:    90 / 188] Training loss: 0.836
# [Epoch: 39 / 200, Iter:   135 / 188] Training loss: 0.841
# [Epoch: 39 / 200, Iter:   180 / 188] Training loss: 0.834
# [Epoch: 39 / 200] Validation loss: 0.829
# [Epoch: 40 / 200, Iter:    45 / 188] Training loss: 0.783
# [Epoch: 40 / 200, Iter:    90 / 188] Training loss: 0.808
# [Epoch: 40 / 200, Iter:   135 / 188] Training loss: 0.825
# [Epoch: 40 / 200, Iter:   180 / 188] Training loss: 0.828
# [Epoch: 40 / 200] Validation loss: 0.884
# [Epoch: 41 / 200, Iter:    45 / 188] Training loss: 0.810
# [Epoch: 41 / 200, Iter:    90 / 188] Training loss: 0.812
# [Epoch: 41 / 200, Iter:   135 / 188] Training loss: 0.829
# [Epoch: 41 / 200, Iter:   180 / 188] Training loss: 0.826
# [Epoch: 41 / 200] Validation loss: 0.817
# [Epoch: 42 / 200, Iter:    45 / 188] Training loss: 0.791
# [Epoch: 42 / 200, Iter:    90 / 188] Training loss: 0.807
# [Epoch: 42 / 200, Iter:   135 / 188] Training loss: 0.810
# [Epoch: 42 / 200, Iter:   180 / 188] Training loss: 0.818
# [Epoch: 42 / 200] Validation loss: 0.827
# [Epoch: 43 / 200, Iter:    45 / 188] Training loss: 0.787
# [Epoch: 43 / 200, Iter:    90 / 188] Training loss: 0.800
# [Epoch: 43 / 200, Iter:   135 / 188] Training loss: 0.804
# [Epoch: 43 / 200, Iter:   180 / 188] Training loss: 0.809
# [Epoch: 43 / 200] Validation loss: 0.821
# [Epoch: 44 / 200, Iter:    45 / 188] Training loss: 0.839
# [Epoch: 44 / 200, Iter:    90 / 188] Training loss: 0.821
# [Epoch: 44 / 200, Iter:   135 / 188] Training loss: 0.814
# [Epoch: 44 / 200, Iter:   180 / 188] Training loss: 0.808
# [Epoch: 44 / 200] Validation loss: 0.813
# [Epoch: 45 / 200, Iter:    45 / 188] Training loss: 0.792
# [Epoch: 45 / 200, Iter:    90 / 188] Training loss: 0.790
# [Epoch: 45 / 200, Iter:   135 / 188] Training loss: 0.804
# [Epoch: 45 / 200, Iter:   180 / 188] Training loss: 0.796
# [Epoch: 45 / 200] Validation loss: 0.835
# [Epoch: 46 / 200, Iter:    45 / 188] Training loss: 0.762
# [Epoch: 46 / 200, Iter:    90 / 188] Training loss: 0.803
# [Epoch: 46 / 200, Iter:   135 / 188] Training loss: 0.803
# [Epoch: 46 / 200, Iter:   180 / 188] Training loss: 0.809
# [Epoch: 46 / 200] Validation loss: 0.842
# [Epoch: 47 / 200, Iter:    45 / 188] Training loss: 0.790
# [Epoch: 47 / 200, Iter:    90 / 188] Training loss: 0.789
# [Epoch: 47 / 200, Iter:   135 / 188] Training loss: 0.791
# [Epoch: 47 / 200, Iter:   180 / 188] Training loss: 0.794
# [Epoch: 47 / 200] Validation loss: 0.813
# [Epoch: 48 / 200, Iter:    45 / 188] Training loss: 0.782
# [Epoch: 48 / 200, Iter:    90 / 188] Training loss: 0.771
# [Epoch: 48 / 200, Iter:   135 / 188] Training loss: 0.789
# [Epoch: 48 / 200, Iter:   180 / 188] Training loss: 0.795
# [Epoch: 48 / 200] Validation loss: 0.801
# [Epoch: 49 / 200, Iter:    45 / 188] Training loss: 0.802
# [Epoch: 49 / 200, Iter:    90 / 188] Training loss: 0.786
# [Epoch: 49 / 200, Iter:   135 / 188] Training loss: 0.796
# [Epoch: 49 / 200, Iter:   180 / 188] Training loss: 0.784
# [Epoch: 49 / 200] Validation loss: 0.822
# [Epoch: 50 / 200, Iter:    45 / 188] Training loss: 0.779
# [Epoch: 50 / 200, Iter:    90 / 188] Training loss: 0.758
# [Epoch: 50 / 200, Iter:   135 / 188] Training loss: 0.774
# [Epoch: 50 / 200, Iter:   180 / 188] Training loss: 0.786
# [Epoch: 50 / 200] Validation loss: 0.821
# [Epoch: 51 / 200, Iter:    45 / 188] Training loss: 0.803
# [Epoch: 51 / 200, Iter:    90 / 188] Training loss: 0.792
# [Epoch: 51 / 200, Iter:   135 / 188] Training loss: 0.785
# [Epoch: 51 / 200, Iter:   180 / 188] Training loss: 0.788
# [Epoch: 51 / 200] Validation loss: 0.774
# [Epoch: 52 / 200, Iter:    45 / 188] Training loss: 0.781
# [Epoch: 52 / 200, Iter:    90 / 188] Training loss: 0.764
# [Epoch: 52 / 200, Iter:   135 / 188] Training loss: 0.764
# [Epoch: 52 / 200, Iter:   180 / 188] Training loss: 0.765
# [Epoch: 52 / 200] Validation loss: 0.807
# [Epoch: 53 / 200, Iter:    45 / 188] Training loss: 0.788
# [Epoch: 53 / 200, Iter:    90 / 188] Training loss: 0.769
# [Epoch: 53 / 200, Iter:   135 / 188] Training loss: 0.777
# [Epoch: 53 / 200, Iter:   180 / 188] Training loss: 0.777
# [Epoch: 53 / 200] Validation loss: 0.813
# [Epoch: 54 / 200, Iter:    45 / 188] Training loss: 0.773
# [Epoch: 54 / 200, Iter:    90 / 188] Training loss: 0.762
# [Epoch: 54 / 200, Iter:   135 / 188] Training loss: 0.749
# [Epoch: 54 / 200, Iter:   180 / 188] Training loss: 0.749
# [Epoch: 54 / 200] Validation loss: 0.789
# [Epoch: 55 / 200, Iter:    45 / 188] Training loss: 0.782
# [Epoch: 55 / 200, Iter:    90 / 188] Training loss: 0.766
# [Epoch: 55 / 200, Iter:   135 / 188] Training loss: 0.771
# [Epoch: 55 / 200, Iter:   180 / 188] Training loss: 0.763
# [Epoch: 55 / 200] Validation loss: 0.770
# [Epoch: 56 / 200, Iter:    45 / 188] Training loss: 0.744
# [Epoch: 56 / 200, Iter:    90 / 188] Training loss: 0.763
# [Epoch: 56 / 200, Iter:   135 / 188] Training loss: 0.763
# [Epoch: 56 / 200, Iter:   180 / 188] Training loss: 0.756
# [Epoch: 56 / 200] Validation loss: 0.810
# [Epoch: 57 / 200, Iter:    45 / 188] Training loss: 0.754
# [Epoch: 57 / 200, Iter:    90 / 188] Training loss: 0.760
# [Epoch: 57 / 200, Iter:   135 / 188] Training loss: 0.748
# [Epoch: 57 / 200, Iter:   180 / 188] Training loss: 0.756
# [Epoch: 57 / 200] Validation loss: 0.780
# [Epoch: 58 / 200, Iter:    45 / 188] Training loss: 0.724
# [Epoch: 58 / 200, Iter:    90 / 188] Training loss: 0.732
# [Epoch: 58 / 200, Iter:   135 / 188] Training loss: 0.732
# [Epoch: 58 / 200, Iter:   180 / 188] Training loss: 0.742
# [Epoch: 58 / 200] Validation loss: 0.831
# [Epoch: 59 / 200, Iter:    45 / 188] Training loss: 0.759
# [Epoch: 59 / 200, Iter:    90 / 188] Training loss: 0.759
# [Epoch: 59 / 200, Iter:   135 / 188] Training loss: 0.751
# [Epoch: 59 / 200, Iter:   180 / 188] Training loss: 0.749
# [Epoch: 59 / 200] Validation loss: 0.776
# [Epoch: 60 / 200, Iter:    45 / 188] Training loss: 0.802
# [Epoch: 60 / 200, Iter:    90 / 188] Training loss: 0.767
# [Epoch: 60 / 200, Iter:   135 / 188] Training loss: 0.751
# [Epoch: 60 / 200, Iter:   180 / 188] Training loss: 0.741
# [Epoch: 60 / 200] Validation loss: 0.809
# [Epoch: 61 / 200, Iter:    45 / 188] Training loss: 0.718
# [Epoch: 61 / 200, Iter:    90 / 188] Training loss: 0.750
# [Epoch: 61 / 200, Iter:   135 / 188] Training loss: 0.749
# [Epoch: 61 / 200, Iter:   180 / 188] Training loss: 0.740
# [Epoch: 61 / 200] Validation loss: 0.779
# [Epoch: 62 / 200, Iter:    45 / 188] Training loss: 0.754
# [Epoch: 62 / 200, Iter:    90 / 188] Training loss: 0.748
# [Epoch: 62 / 200, Iter:   135 / 188] Training loss: 0.743
# [Epoch: 62 / 200, Iter:   180 / 188] Training loss: 0.744
# [Epoch: 62 / 200] Validation loss: 0.773
# [Epoch: 63 / 200, Iter:    45 / 188] Training loss: 0.732
# [Epoch: 63 / 200, Iter:    90 / 188] Training loss: 0.748
# [Epoch: 63 / 200, Iter:   135 / 188] Training loss: 0.747
# [Epoch: 63 / 200, Iter:   180 / 188] Training loss: 0.742
# [Epoch: 63 / 200] Validation loss: 0.760
# [Epoch: 64 / 200, Iter:    45 / 188] Training loss: 0.720
# [Epoch: 64 / 200, Iter:    90 / 188] Training loss: 0.736
# [Epoch: 64 / 200, Iter:   135 / 188] Training loss: 0.726
# [Epoch: 64 / 200, Iter:   180 / 188] Training loss: 0.727
# [Epoch: 64 / 200] Validation loss: 0.782
# [Epoch: 65 / 200, Iter:    45 / 188] Training loss: 0.713
# [Epoch: 65 / 200, Iter:    90 / 188] Training loss: 0.739
# [Epoch: 65 / 200, Iter:   135 / 188] Training loss: 0.742
# [Epoch: 65 / 200, Iter:   180 / 188] Training loss: 0.736
# [Epoch: 65 / 200] Validation loss: 0.767
# [Epoch: 66 / 200, Iter:    45 / 188] Training loss: 0.726
# [Epoch: 66 / 200, Iter:    90 / 188] Training loss: 0.723
# [Epoch: 66 / 200, Iter:   135 / 188] Training loss: 0.732
# [Epoch: 66 / 200, Iter:   180 / 188] Training loss: 0.733
# [Epoch: 66 / 200] Validation loss: 0.782
# [Epoch: 67 / 200, Iter:    45 / 188] Training loss: 0.741
# [Epoch: 67 / 200, Iter:    90 / 188] Training loss: 0.754
# [Epoch: 67 / 200, Iter:   135 / 188] Training loss: 0.737
# [Epoch: 67 / 200, Iter:   180 / 188] Training loss: 0.721
# [Epoch: 67 / 200] Validation loss: 0.749
# [Epoch: 68 / 200, Iter:    45 / 188] Training loss: 0.741
# [Epoch: 68 / 200, Iter:    90 / 188] Training loss: 0.718
# [Epoch: 68 / 200, Iter:   135 / 188] Training loss: 0.710
# [Epoch: 68 / 200, Iter:   180 / 188] Training loss: 0.709
# [Epoch: 68 / 200] Validation loss: 0.769
# [Epoch: 69 / 200, Iter:    45 / 188] Training loss: 0.676
# [Epoch: 69 / 200, Iter:    90 / 188] Training loss: 0.709
# [Epoch: 69 / 200, Iter:   135 / 188] Training loss: 0.713
# [Epoch: 69 / 200, Iter:   180 / 188] Training loss: 0.704
# [Epoch: 69 / 200] Validation loss: 0.762
# [Epoch: 70 / 200, Iter:    45 / 188] Training loss: 0.734
# [Epoch: 70 / 200, Iter:    90 / 188] Training loss: 0.702
# [Epoch: 70 / 200, Iter:   135 / 188] Training loss: 0.711
# [Epoch: 70 / 200, Iter:   180 / 188] Training loss: 0.714
# [Epoch: 70 / 200] Validation loss: 0.761
# [Epoch: 71 / 200, Iter:    45 / 188] Training loss: 0.716
# [Epoch: 71 / 200, Iter:    90 / 188] Training loss: 0.713
# [Epoch: 71 / 200, Iter:   135 / 188] Training loss: 0.703
# [Epoch: 71 / 200, Iter:   180 / 188] Training loss: 0.716
# [Epoch: 71 / 200] Validation loss: 0.726
# [Epoch: 72 / 200, Iter:    45 / 188] Training loss: 0.688
# [Epoch: 72 / 200, Iter:    90 / 188] Training loss: 0.699
# [Epoch: 72 / 200, Iter:   135 / 188] Training loss: 0.709
# [Epoch: 72 / 200, Iter:   180 / 188] Training loss: 0.711
# [Epoch: 72 / 200] Validation loss: 0.758
# [Epoch: 73 / 200, Iter:    45 / 188] Training loss: 0.691
# [Epoch: 73 / 200, Iter:    90 / 188] Training loss: 0.712
# [Epoch: 73 / 200, Iter:   135 / 188] Training loss: 0.703
# [Epoch: 73 / 200, Iter:   180 / 188] Training loss: 0.708
# [Epoch: 73 / 200] Validation loss: 0.735
# [Epoch: 74 / 200, Iter:    45 / 188] Training loss: 0.676
# [Epoch: 74 / 200, Iter:    90 / 188] Training loss: 0.703
# [Epoch: 74 / 200, Iter:   135 / 188] Training loss: 0.707
# [Epoch: 74 / 200, Iter:   180 / 188] Training loss: 0.711
# [Epoch: 74 / 200] Validation loss: 0.739
# [Epoch: 75 / 200, Iter:    45 / 188] Training loss: 0.722
# [Epoch: 75 / 200, Iter:    90 / 188] Training loss: 0.696
# [Epoch: 75 / 200, Iter:   135 / 188] Training loss: 0.697
# [Epoch: 75 / 200, Iter:   180 / 188] Training loss: 0.691
# [Epoch: 75 / 200] Validation loss: 0.745
# [Epoch: 76 / 200, Iter:    45 / 188] Training loss: 0.690
# [Epoch: 76 / 200, Iter:    90 / 188] Training loss: 0.681
# [Epoch: 76 / 200, Iter:   135 / 188] Training loss: 0.680
# [Epoch: 76 / 200, Iter:   180 / 188] Training loss: 0.682
# [Epoch: 76 / 200] Validation loss: 0.770
# [Epoch: 77 / 200, Iter:    45 / 188] Training loss: 0.673
# [Epoch: 77 / 200, Iter:    90 / 188] Training loss: 0.682
# [Epoch: 77 / 200, Iter:   135 / 188] Training loss: 0.684
# [Epoch: 77 / 200, Iter:   180 / 188] Training loss: 0.683
# [Epoch: 77 / 200] Validation loss: 0.717
# [Epoch: 78 / 200, Iter:    45 / 188] Training loss: 0.715
# [Epoch: 78 / 200, Iter:    90 / 188] Training loss: 0.695
# [Epoch: 78 / 200, Iter:   135 / 188] Training loss: 0.689
# [Epoch: 78 / 200, Iter:   180 / 188] Training loss: 0.696
# [Epoch: 78 / 200] Validation loss: 0.735
# [Epoch: 79 / 200, Iter:    45 / 188] Training loss: 0.714
# [Epoch: 79 / 200, Iter:    90 / 188] Training loss: 0.689
# [Epoch: 79 / 200, Iter:   135 / 188] Training loss: 0.682
# [Epoch: 79 / 200, Iter:   180 / 188] Training loss: 0.685
# [Epoch: 79 / 200] Validation loss: 0.779
# [Epoch: 80 / 200, Iter:    45 / 188] Training loss: 0.696
# [Epoch: 80 / 200, Iter:    90 / 188] Training loss: 0.693
# [Epoch: 80 / 200, Iter:   135 / 188] Training loss: 0.685
# [Epoch: 80 / 200, Iter:   180 / 188] Training loss: 0.690
# [Epoch: 80 / 200] Validation loss: 0.750
# [Epoch: 81 / 200, Iter:    45 / 188] Training loss: 0.661
# [Epoch: 81 / 200, Iter:    90 / 188] Training loss: 0.675
# [Epoch: 81 / 200, Iter:   135 / 188] Training loss: 0.679
# [Epoch: 81 / 200, Iter:   180 / 188] Training loss: 0.683
# [Epoch: 81 / 200] Validation loss: 0.797
# [Epoch: 82 / 200, Iter:    45 / 188] Training loss: 0.690
# [Epoch: 82 / 200, Iter:    90 / 188] Training loss: 0.671
# [Epoch: 82 / 200, Iter:   135 / 188] Training loss: 0.679
# [Epoch: 82 / 200, Iter:   180 / 188] Training loss: 0.672
# [Epoch: 82 / 200] Validation loss: 0.731
# [Epoch: 83 / 200, Iter:    45 / 188] Training loss: 0.640
# [Epoch: 83 / 200, Iter:    90 / 188] Training loss: 0.674
# [Epoch: 83 / 200, Iter:   135 / 188] Training loss: 0.675
# [Epoch: 83 / 200, Iter:   180 / 188] Training loss: 0.677
# [Epoch: 83 / 200] Validation loss: 0.715
# [Epoch: 84 / 200, Iter:    45 / 188] Training loss: 0.655
# [Epoch: 84 / 200, Iter:    90 / 188] Training loss: 0.674
# [Epoch: 84 / 200, Iter:   135 / 188] Training loss: 0.663
# [Epoch: 84 / 200, Iter:   180 / 188] Training loss: 0.674
# [Epoch: 84 / 200] Validation loss: 0.736
# [Epoch: 85 / 200, Iter:    45 / 188] Training loss: 0.647
# [Epoch: 85 / 200, Iter:    90 / 188] Training loss: 0.659
# [Epoch: 85 / 200, Iter:   135 / 188] Training loss: 0.666
# [Epoch: 85 / 200, Iter:   180 / 188] Training loss: 0.668
# [Epoch: 85 / 200] Validation loss: 0.723
# [Epoch: 86 / 200, Iter:    45 / 188] Training loss: 0.668
# [Epoch: 86 / 200, Iter:    90 / 188] Training loss: 0.661
# [Epoch: 86 / 200, Iter:   135 / 188] Training loss: 0.660
# [Epoch: 86 / 200, Iter:   180 / 188] Training loss: 0.666
# [Epoch: 86 / 200] Validation loss: 0.738
# [Epoch: 87 / 200, Iter:    45 / 188] Training loss: 0.676
# [Epoch: 87 / 200, Iter:    90 / 188] Training loss: 0.680
# [Epoch: 87 / 200, Iter:   135 / 188] Training loss: 0.670
# [Epoch: 87 / 200, Iter:   180 / 188] Training loss: 0.674
# [Epoch: 87 / 200] Validation loss: 0.727
# [Epoch: 88 / 200, Iter:    45 / 188] Training loss: 0.662
# [Epoch: 88 / 200, Iter:    90 / 188] Training loss: 0.657
# [Epoch: 88 / 200, Iter:   135 / 188] Training loss: 0.660
# [Epoch: 88 / 200, Iter:   180 / 188] Training loss: 0.674
# [Epoch: 88 / 200] Validation loss: 0.705
# [Epoch: 89 / 200, Iter:    45 / 188] Training loss: 0.686
# [Epoch: 89 / 200, Iter:    90 / 188] Training loss: 0.685
# [Epoch: 89 / 200, Iter:   135 / 188] Training loss: 0.667
# [Epoch: 89 / 200, Iter:   180 / 188] Training loss: 0.664
# [Epoch: 89 / 200] Validation loss: 0.722
# [Epoch: 90 / 200, Iter:    45 / 188] Training loss: 0.684
# [Epoch: 90 / 200, Iter:    90 / 188] Training loss: 0.651
# [Epoch: 90 / 200, Iter:   135 / 188] Training loss: 0.655
# [Epoch: 90 / 200, Iter:   180 / 188] Training loss: 0.663
# [Epoch: 90 / 200] Validation loss: 0.711
# [Epoch: 91 / 200, Iter:    45 / 188] Training loss: 0.623
# [Epoch: 91 / 200, Iter:    90 / 188] Training loss: 0.652
# [Epoch: 91 / 200, Iter:   135 / 188] Training loss: 0.651
# [Epoch: 91 / 200, Iter:   180 / 188] Training loss: 0.663
# [Epoch: 91 / 200] Validation loss: 0.724
# [Epoch: 92 / 200, Iter:    45 / 188] Training loss: 0.632
# [Epoch: 92 / 200, Iter:    90 / 188] Training loss: 0.646
# [Epoch: 92 / 200, Iter:   135 / 188] Training loss: 0.664
# [Epoch: 92 / 200, Iter:   180 / 188] Training loss: 0.657
# [Epoch: 92 / 200] Validation loss: 0.723
# [Epoch: 93 / 200, Iter:    45 / 188] Training loss: 0.640
# [Epoch: 93 / 200, Iter:    90 / 188] Training loss: 0.658
# [Epoch: 93 / 200, Iter:   135 / 188] Training loss: 0.658
# [Epoch: 93 / 200, Iter:   180 / 188] Training loss: 0.656
# [Epoch: 93 / 200] Validation loss: 0.708
# [Epoch: 94 / 200, Iter:    45 / 188] Training loss: 0.619
# [Epoch: 94 / 200, Iter:    90 / 188] Training loss: 0.627
# [Epoch: 94 / 200, Iter:   135 / 188] Training loss: 0.639
# [Epoch: 94 / 200, Iter:   180 / 188] Training loss: 0.642
# [Epoch: 94 / 200] Validation loss: 0.719
# [Epoch: 95 / 200, Iter:    45 / 188] Training loss: 0.662
# [Epoch: 95 / 200, Iter:    90 / 188] Training loss: 0.633
# [Epoch: 95 / 200, Iter:   135 / 188] Training loss: 0.645
# [Epoch: 95 / 200, Iter:   180 / 188] Training loss: 0.638
# [Epoch: 95 / 200] Validation loss: 0.734
# [Epoch: 96 / 200, Iter:    45 / 188] Training loss: 0.679
# [Epoch: 96 / 200, Iter:    90 / 188] Training loss: 0.659
# [Epoch: 96 / 200, Iter:   135 / 188] Training loss: 0.656
# [Epoch: 96 / 200, Iter:   180 / 188] Training loss: 0.654
# [Epoch: 96 / 200] Validation loss: 0.698
# [Epoch: 97 / 200, Iter:    45 / 188] Training loss: 0.650
# [Epoch: 97 / 200, Iter:    90 / 188] Training loss: 0.648
# [Epoch: 97 / 200, Iter:   135 / 188] Training loss: 0.644
# [Epoch: 97 / 200, Iter:   180 / 188] Training loss: 0.647
# [Epoch: 97 / 200] Validation loss: 0.733
# [Epoch: 98 / 200, Iter:    45 / 188] Training loss: 0.645
# [Epoch: 98 / 200, Iter:    90 / 188] Training loss: 0.645
# [Epoch: 98 / 200, Iter:   135 / 188] Training loss: 0.638
# [Epoch: 98 / 200, Iter:   180 / 188] Training loss: 0.644
# [Epoch: 98 / 200] Validation loss: 0.728
# [Epoch: 99 / 200, Iter:    45 / 188] Training loss: 0.641
# [Epoch: 99 / 200, Iter:    90 / 188] Training loss: 0.627
# [Epoch: 99 / 200, Iter:   135 / 188] Training loss: 0.638
# [Epoch: 99 / 200, Iter:   180 / 188] Training loss: 0.641
# [Epoch: 99 / 200] Validation loss: 0.686
# [Epoch: 100 / 200, Iter:    45 / 188] Training loss: 0.633
# [Epoch: 100 / 200, Iter:    90 / 188] Training loss: 0.620
# [Epoch: 100 / 200, Iter:   135 / 188] Training loss: 0.633
# [Epoch: 100 / 200, Iter:   180 / 188] Training loss: 0.641
# [Epoch: 100 / 200] Validation loss: 0.699
# [Epoch: 101 / 200, Iter:    45 / 188] Training loss: 0.645
# [Epoch: 101 / 200, Iter:    90 / 188] Training loss: 0.625
# [Epoch: 101 / 200, Iter:   135 / 188] Training loss: 0.636
# [Epoch: 101 / 200, Iter:   180 / 188] Training loss: 0.641
# [Epoch: 101 / 200] Validation loss: 0.704
# [Epoch: 102 / 200, Iter:    45 / 188] Training loss: 0.654
# [Epoch: 102 / 200, Iter:    90 / 188] Training loss: 0.649
# [Epoch: 102 / 200, Iter:   135 / 188] Training loss: 0.639
# [Epoch: 102 / 200, Iter:   180 / 188] Training loss: 0.640
# [Epoch: 102 / 200] Validation loss: 0.716
# [Epoch: 103 / 200, Iter:    45 / 188] Training loss: 0.640
# [Epoch: 103 / 200, Iter:    90 / 188] Training loss: 0.633
# [Epoch: 103 / 200, Iter:   135 / 188] Training loss: 0.638
# [Epoch: 103 / 200, Iter:   180 / 188] Training loss: 0.637
# [Epoch: 103 / 200] Validation loss: 0.726
# [Epoch: 104 / 200, Iter:    45 / 188] Training loss: 0.598
# [Epoch: 104 / 200, Iter:    90 / 188] Training loss: 0.613
# [Epoch: 104 / 200, Iter:   135 / 188] Training loss: 0.623
# [Epoch: 104 / 200, Iter:   180 / 188] Training loss: 0.634
# [Epoch: 104 / 200] Validation loss: 0.704
# [Epoch: 105 / 200, Iter:    45 / 188] Training loss: 0.588
# [Epoch: 105 / 200, Iter:    90 / 188] Training loss: 0.616
# [Epoch: 105 / 200, Iter:   135 / 188] Training loss: 0.620
# [Epoch: 105 / 200, Iter:   180 / 188] Training loss: 0.623
# [Epoch: 105 / 200] Validation loss: 0.714
# [Epoch: 106 / 200, Iter:    45 / 188] Training loss: 0.615
# [Epoch: 106 / 200, Iter:    90 / 188] Training loss: 0.624
# [Epoch: 106 / 200, Iter:   135 / 188] Training loss: 0.621
# [Epoch: 106 / 200, Iter:   180 / 188] Training loss: 0.622
# [Epoch: 106 / 200] Validation loss: 0.722
# [Epoch: 107 / 200, Iter:    45 / 188] Training loss: 0.616
# [Epoch: 107 / 200, Iter:    90 / 188] Training loss: 0.610
# [Epoch: 107 / 200, Iter:   135 / 188] Training loss: 0.634
# [Epoch: 107 / 200, Iter:   180 / 188] Training loss: 0.623
# [Epoch: 107 / 200] Validation loss: 0.707
# [Epoch: 108 / 200, Iter:    45 / 188] Training loss: 0.625
# [Epoch: 108 / 200, Iter:    90 / 188] Training loss: 0.631
# [Epoch: 108 / 200, Iter:   135 / 188] Training loss: 0.615
# [Epoch: 108 / 200, Iter:   180 / 188] Training loss: 0.625
# [Epoch: 108 / 200] Validation loss: 0.701
# [Epoch: 109 / 200, Iter:    45 / 188] Training loss: 0.620
# [Epoch: 109 / 200, Iter:    90 / 188] Training loss: 0.608
# [Epoch: 109 / 200, Iter:   135 / 188] Training loss: 0.602
# [Epoch: 109 / 200, Iter:   180 / 188] Training loss: 0.614
# [Epoch: 109 / 200] Validation loss: 0.717
# [Epoch: 110 / 200, Iter:    45 / 188] Training loss: 0.639
# [Epoch: 110 / 200, Iter:    90 / 188] Training loss: 0.647
# [Epoch: 110 / 200, Iter:   135 / 188] Training loss: 0.630
# [Epoch: 110 / 200, Iter:   180 / 188] Training loss: 0.635
# [Epoch: 110 / 200] Validation loss: 0.704
# [Epoch: 111 / 200, Iter:    45 / 188] Training loss: 0.601
# [Epoch: 111 / 200, Iter:    90 / 188] Training loss: 0.609
# [Epoch: 111 / 200, Iter:   135 / 188] Training loss: 0.622
# [Epoch: 111 / 200, Iter:   180 / 188] Training loss: 0.613
# [Epoch: 111 / 200] Validation loss: 0.697
# [Epoch: 112 / 200, Iter:    45 / 188] Training loss: 0.626
# [Epoch: 112 / 200, Iter:    90 / 188] Training loss: 0.621
# [Epoch: 112 / 200, Iter:   135 / 188] Training loss: 0.618
# [Epoch: 112 / 200, Iter:   180 / 188] Training loss: 0.617
# [Epoch: 112 / 200] Validation loss: 0.702
# [Epoch: 113 / 200, Iter:    45 / 188] Training loss: 0.642
# [Epoch: 113 / 200, Iter:    90 / 188] Training loss: 0.639
# [Epoch: 113 / 200, Iter:   135 / 188] Training loss: 0.630
# [Epoch: 113 / 200, Iter:   180 / 188] Training loss: 0.624
# [Epoch: 113 / 200] Validation loss: 0.726
# [Epoch: 114 / 200, Iter:    45 / 188] Training loss: 0.641
# [Epoch: 114 / 200, Iter:    90 / 188] Training loss: 0.590
# [Epoch: 114 / 200, Iter:   135 / 188] Training loss: 0.599
# [Epoch: 114 / 200, Iter:   180 / 188] Training loss: 0.608
# [Epoch: 114 / 200] Validation loss: 0.702
# [Epoch: 115 / 200, Iter:    45 / 188] Training loss: 0.591
# [Epoch: 115 / 200, Iter:    90 / 188] Training loss: 0.593
# [Epoch: 115 / 200, Iter:   135 / 188] Training loss: 0.604
# [Epoch: 115 / 200, Iter:   180 / 188] Training loss: 0.613
# [Epoch: 115 / 200] Validation loss: 0.703
# [Epoch: 116 / 200, Iter:    45 / 188] Training loss: 0.639
# [Epoch: 116 / 200, Iter:    90 / 188] Training loss: 0.603
# [Epoch: 116 / 200, Iter:   135 / 188] Training loss: 0.617
# [Epoch: 116 / 200, Iter:   180 / 188] Training loss: 0.615
# [Epoch: 116 / 200] Validation loss: 0.690
# [Epoch: 117 / 200, Iter:    45 / 188] Training loss: 0.602
# [Epoch: 117 / 200, Iter:    90 / 188] Training loss: 0.590
# [Epoch: 117 / 200, Iter:   135 / 188] Training loss: 0.602
# [Epoch: 117 / 200, Iter:   180 / 188] Training loss: 0.617
# [Epoch: 117 / 200] Validation loss: 0.719
# [Epoch: 118 / 200, Iter:    45 / 188] Training loss: 0.633
# [Epoch: 118 / 200, Iter:    90 / 188] Training loss: 0.610
# [Epoch: 118 / 200, Iter:   135 / 188] Training loss: 0.617
# [Epoch: 118 / 200, Iter:   180 / 188] Training loss: 0.612
# [Epoch: 118 / 200] Validation loss: 0.746
# [Epoch: 119 / 200, Iter:    45 / 188] Training loss: 0.610
# [Epoch: 119 / 200, Iter:    90 / 188] Training loss: 0.607
# [Epoch: 119 / 200, Iter:   135 / 188] Training loss: 0.610
# [Epoch: 119 / 200, Iter:   180 / 188] Training loss: 0.602
# [Epoch: 119 / 200] Validation loss: 0.725
# [Epoch: 120 / 200, Iter:    45 / 188] Training loss: 0.567
# [Epoch: 120 / 200, Iter:    90 / 188] Training loss: 0.591
# [Epoch: 120 / 200, Iter:   135 / 188] Training loss: 0.592
# [Epoch: 120 / 200, Iter:   180 / 188] Training loss: 0.608
# [Epoch: 120 / 200] Validation loss: 0.695
# [Epoch: 121 / 200, Iter:    45 / 188] Training loss: 0.594
# [Epoch: 121 / 200, Iter:    90 / 188] Training loss: 0.594
# [Epoch: 121 / 200, Iter:   135 / 188] Training loss: 0.599
# [Epoch: 121 / 200, Iter:   180 / 188] Training loss: 0.599
# [Epoch: 121 / 200] Validation loss: 0.722
# [Epoch: 122 / 200, Iter:    45 / 188] Training loss: 0.592
# [Epoch: 122 / 200, Iter:    90 / 188] Training loss: 0.595
# [Epoch: 122 / 200, Iter:   135 / 188] Training loss: 0.607
# [Epoch: 122 / 200, Iter:   180 / 188] Training loss: 0.600
# [Epoch: 122 / 200] Validation loss: 0.703
# [Epoch: 123 / 200, Iter:    45 / 188] Training loss: 0.598
# [Epoch: 123 / 200, Iter:    90 / 188] Training loss: 0.604
# [Epoch: 123 / 200, Iter:   135 / 188] Training loss: 0.608
# [Epoch: 123 / 200, Iter:   180 / 188] Training loss: 0.601
# [Epoch: 123 / 200] Validation loss: 0.692
# [Epoch: 124 / 200, Iter:    45 / 188] Training loss: 0.599
# [Epoch: 124 / 200, Iter:    90 / 188] Training loss: 0.607
# [Epoch: 124 / 200, Iter:   135 / 188] Training loss: 0.599
# [Epoch: 124 / 200, Iter:   180 / 188] Training loss: 0.599
# [Epoch: 124 / 200] Validation loss: 0.707
# [Epoch: 125 / 200, Iter:    45 / 188] Training loss: 0.591
# [Epoch: 125 / 200, Iter:    90 / 188] Training loss: 0.576
# [Epoch: 125 / 200, Iter:   135 / 188] Training loss: 0.585
# [Epoch: 125 / 200, Iter:   180 / 188] Training loss: 0.587
# [Epoch: 125 / 200] Validation loss: 0.699
# [Epoch: 126 / 200, Iter:    45 / 188] Training loss: 0.585
# [Epoch: 126 / 200, Iter:    90 / 188] Training loss: 0.602
# [Epoch: 126 / 200, Iter:   135 / 188] Training loss: 0.598
# [Epoch: 126 / 200, Iter:   180 / 188] Training loss: 0.595
# [Epoch: 126 / 200] Validation loss: 0.694
# [Epoch: 127 / 200, Iter:    45 / 188] Training loss: 0.607
# [Epoch: 127 / 200, Iter:    90 / 188] Training loss: 0.594
# [Epoch: 127 / 200, Iter:   135 / 188] Training loss: 0.590
# [Epoch: 127 / 200, Iter:   180 / 188] Training loss: 0.587
# [Epoch: 127 / 200] Validation loss: 0.708
# [Epoch: 128 / 200, Iter:    45 / 188] Training loss: 0.567
# [Epoch: 128 / 200, Iter:    90 / 188] Training loss: 0.590
# [Epoch: 128 / 200, Iter:   135 / 188] Training loss: 0.582
# [Epoch: 128 / 200, Iter:   180 / 188] Training loss: 0.585
# [Epoch: 128 / 200] Validation loss: 0.673
# [Epoch: 129 / 200, Iter:    45 / 188] Training loss: 0.600
# [Epoch: 129 / 200, Iter:    90 / 188] Training loss: 0.598
# [Epoch: 129 / 200, Iter:   135 / 188] Training loss: 0.592
# [Epoch: 129 / 200, Iter:   180 / 188] Training loss: 0.597
# [Epoch: 129 / 200] Validation loss: 0.702
# [Epoch: 130 / 200, Iter:    45 / 188] Training loss: 0.562
# [Epoch: 130 / 200, Iter:    90 / 188] Training loss: 0.571
# [Epoch: 130 / 200, Iter:   135 / 188] Training loss: 0.586
# [Epoch: 130 / 200, Iter:   180 / 188] Training loss: 0.589
# [Epoch: 130 / 200] Validation loss: 0.701
# [Epoch: 131 / 200, Iter:    45 / 188] Training loss: 0.618
# [Epoch: 131 / 200, Iter:    90 / 188] Training loss: 0.609
# [Epoch: 131 / 200, Iter:   135 / 188] Training loss: 0.600
# [Epoch: 131 / 200, Iter:   180 / 188] Training loss: 0.593
# [Epoch: 131 / 200] Validation loss: 0.698
# [Epoch: 132 / 200, Iter:    45 / 188] Training loss: 0.566
# [Epoch: 132 / 200, Iter:    90 / 188] Training loss: 0.580
# [Epoch: 132 / 200, Iter:   135 / 188] Training loss: 0.572
# [Epoch: 132 / 200, Iter:   180 / 188] Training loss: 0.572
# [Epoch: 132 / 200] Validation loss: 0.707
# [Epoch: 133 / 200, Iter:    45 / 188] Training loss: 0.578
# [Epoch: 133 / 200, Iter:    90 / 188] Training loss: 0.579
# [Epoch: 133 / 200, Iter:   135 / 188] Training loss: 0.568
# [Epoch: 133 / 200, Iter:   180 / 188] Training loss: 0.577
# [Epoch: 133 / 200] Validation loss: 0.687
# [Epoch: 134 / 200, Iter:    45 / 188] Training loss: 0.540
# [Epoch: 134 / 200, Iter:    90 / 188] Training loss: 0.556
# [Epoch: 134 / 200, Iter:   135 / 188] Training loss: 0.567
# [Epoch: 134 / 200, Iter:   180 / 188] Training loss: 0.570
# [Epoch: 134 / 200] Validation loss: 0.695
# [Epoch: 135 / 200, Iter:    45 / 188] Training loss: 0.586
# [Epoch: 135 / 200, Iter:    90 / 188] Training loss: 0.608
# [Epoch: 135 / 200, Iter:   135 / 188] Training loss: 0.587
# [Epoch: 135 / 200, Iter:   180 / 188] Training loss: 0.584
# [Epoch: 135 / 200] Validation loss: 0.686
# [Epoch: 136 / 200, Iter:    45 / 188] Training loss: 0.592
# [Epoch: 136 / 200, Iter:    90 / 188] Training loss: 0.592
# [Epoch: 136 / 200, Iter:   135 / 188] Training loss: 0.581
# [Epoch: 136 / 200, Iter:   180 / 188] Training loss: 0.575
# [Epoch: 136 / 200] Validation loss: 0.698
# [Epoch: 137 / 200, Iter:    45 / 188] Training loss: 0.554
# [Epoch: 137 / 200, Iter:    90 / 188] Training loss: 0.560
# [Epoch: 137 / 200, Iter:   135 / 188] Training loss: 0.565
# [Epoch: 137 / 200, Iter:   180 / 188] Training loss: 0.572
# [Epoch: 137 / 200] Validation loss: 0.691
# [Epoch: 138 / 200, Iter:    45 / 188] Training loss: 0.552
# [Epoch: 138 / 200, Iter:    90 / 188] Training loss: 0.567
# [Epoch: 138 / 200, Iter:   135 / 188] Training loss: 0.586
# [Epoch: 138 / 200, Iter:   180 / 188] Training loss: 0.575
# [Epoch: 138 / 200] Validation loss: 0.689
# [Epoch: 139 / 200, Iter:    45 / 188] Training loss: 0.596
# [Epoch: 139 / 200, Iter:    90 / 188] Training loss: 0.579
# [Epoch: 139 / 200, Iter:   135 / 188] Training loss: 0.583
# [Epoch: 139 / 200, Iter:   180 / 188] Training loss: 0.572
# [Epoch: 139 / 200] Validation loss: 0.700
# [Epoch: 140 / 200, Iter:    45 / 188] Training loss: 0.561
# [Epoch: 140 / 200, Iter:    90 / 188] Training loss: 0.575
# [Epoch: 140 / 200, Iter:   135 / 188] Training loss: 0.562
# [Epoch: 140 / 200, Iter:   180 / 188] Training loss: 0.575
# [Epoch: 140 / 200] Validation loss: 0.680
# [Epoch: 141 / 200, Iter:    45 / 188] Training loss: 0.577
# [Epoch: 141 / 200, Iter:    90 / 188] Training loss: 0.597
# [Epoch: 141 / 200, Iter:   135 / 188] Training loss: 0.580
# [Epoch: 141 / 200, Iter:   180 / 188] Training loss: 0.578
# [Epoch: 141 / 200] Validation loss: 0.688
# [Epoch: 142 / 200, Iter:    45 / 188] Training loss: 0.561
# [Epoch: 142 / 200, Iter:    90 / 188] Training loss: 0.574
# [Epoch: 142 / 200, Iter:   135 / 188] Training loss: 0.564
# [Epoch: 142 / 200, Iter:   180 / 188] Training loss: 0.570
# [Epoch: 142 / 200] Validation loss: 0.693
# [Epoch: 143 / 200, Iter:    45 / 188] Training loss: 0.557
# [Epoch: 143 / 200, Iter:    90 / 188] Training loss: 0.545
# [Epoch: 143 / 200, Iter:   135 / 188] Training loss: 0.548
# [Epoch: 143 / 200, Iter:   180 / 188] Training loss: 0.559
# [Epoch: 143 / 200] Validation loss: 0.682
# [Epoch: 144 / 200, Iter:    45 / 188] Training loss: 0.543
# [Epoch: 144 / 200, Iter:    90 / 188] Training loss: 0.554
# [Epoch: 144 / 200, Iter:   135 / 188] Training loss: 0.555
# [Epoch: 144 / 200, Iter:   180 / 188] Training loss: 0.557
# [Epoch: 144 / 200] Validation loss: 0.698
# [Epoch: 145 / 200, Iter:    45 / 188] Training loss: 0.519
# [Epoch: 145 / 200, Iter:    90 / 188] Training loss: 0.543
# [Epoch: 145 / 200, Iter:   135 / 188] Training loss: 0.552
# [Epoch: 145 / 200, Iter:   180 / 188] Training loss: 0.556
# [Epoch: 145 / 200] Validation loss: 0.680
# [Epoch: 146 / 200, Iter:    45 / 188] Training loss: 0.576
# [Epoch: 146 / 200, Iter:    90 / 188] Training loss: 0.579
# [Epoch: 146 / 200, Iter:   135 / 188] Training loss: 0.569
# [Epoch: 146 / 200, Iter:   180 / 188] Training loss: 0.557
# [Epoch: 146 / 200] Validation loss: 0.726
# [Epoch: 147 / 200, Iter:    45 / 188] Training loss: 0.570
# [Epoch: 147 / 200, Iter:    90 / 188] Training loss: 0.560
# [Epoch: 147 / 200, Iter:   135 / 188] Training loss: 0.559
# [Epoch: 147 / 200, Iter:   180 / 188] Training loss: 0.566
# [Epoch: 147 / 200] Validation loss: 0.708
# [Epoch: 148 / 200, Iter:    45 / 188] Training loss: 0.569
# [Epoch: 148 / 200, Iter:    90 / 188] Training loss: 0.579
# [Epoch: 148 / 200, Iter:   135 / 188] Training loss: 0.582
# [Epoch: 148 / 200, Iter:   180 / 188] Training loss: 0.566
# [Epoch: 148 / 200] Validation loss: 0.690
# [Epoch: 149 / 200, Iter:    45 / 188] Training loss: 0.599
# [Epoch: 149 / 200, Iter:    90 / 188] Training loss: 0.593
# [Epoch: 149 / 200, Iter:   135 / 188] Training loss: 0.576
# [Epoch: 149 / 200, Iter:   180 / 188] Training loss: 0.573
# [Epoch: 149 / 200] Validation loss: 0.689
# [Epoch: 150 / 200, Iter:    45 / 188] Training loss: 0.560
# [Epoch: 150 / 200, Iter:    90 / 188] Training loss: 0.555
# [Epoch: 150 / 200, Iter:   135 / 188] Training loss: 0.553
# [Epoch: 150 / 200, Iter:   180 / 188] Training loss: 0.554
# [Epoch: 150 / 200] Validation loss: 0.658
# [Epoch: 151 / 200, Iter:    45 / 188] Training loss: 0.564
# [Epoch: 151 / 200, Iter:    90 / 188] Training loss: 0.550
# [Epoch: 151 / 200, Iter:   135 / 188] Training loss: 0.540
# [Epoch: 151 / 200, Iter:   180 / 188] Training loss: 0.551
# [Epoch: 151 / 200] Validation loss: 0.668
# [Epoch: 152 / 200, Iter:    45 / 188] Training loss: 0.521
# [Epoch: 152 / 200, Iter:    90 / 188] Training loss: 0.534
# [Epoch: 152 / 200, Iter:   135 / 188] Training loss: 0.545
# [Epoch: 152 / 200, Iter:   180 / 188] Training loss: 0.555
# [Epoch: 152 / 200] Validation loss: 0.697
# [Epoch: 153 / 200, Iter:    45 / 188] Training loss: 0.541
# [Epoch: 153 / 200, Iter:    90 / 188] Training loss: 0.537
# [Epoch: 153 / 200, Iter:   135 / 188] Training loss: 0.538
# [Epoch: 153 / 200, Iter:   180 / 188] Training loss: 0.543
# [Epoch: 153 / 200] Validation loss: 0.734
# [Epoch: 154 / 200, Iter:    45 / 188] Training loss: 0.528
# [Epoch: 154 / 200, Iter:    90 / 188] Training loss: 0.522
# [Epoch: 154 / 200, Iter:   135 / 188] Training loss: 0.545
# [Epoch: 154 / 200, Iter:   180 / 188] Training loss: 0.559
# [Epoch: 154 / 200] Validation loss: 0.677
# [Epoch: 155 / 200, Iter:    45 / 188] Training loss: 0.529
# [Epoch: 155 / 200, Iter:    90 / 188] Training loss: 0.551
# [Epoch: 155 / 200, Iter:   135 / 188] Training loss: 0.553
# [Epoch: 155 / 200, Iter:   180 / 188] Training loss: 0.553
# [Epoch: 155 / 200] Validation loss: 0.689
# [Epoch: 156 / 200, Iter:    45 / 188] Training loss: 0.558
# [Epoch: 156 / 200, Iter:    90 / 188] Training loss: 0.559
# [Epoch: 156 / 200, Iter:   135 / 188] Training loss: 0.560
# [Epoch: 156 / 200, Iter:   180 / 188] Training loss: 0.543
# [Epoch: 156 / 200] Validation loss: 0.694
# [Epoch: 157 / 200, Iter:    45 / 188] Training loss: 0.548
# [Epoch: 157 / 200, Iter:    90 / 188] Training loss: 0.537
# [Epoch: 157 / 200, Iter:   135 / 188] Training loss: 0.545
# [Epoch: 157 / 200, Iter:   180 / 188] Training loss: 0.548
# [Epoch: 157 / 200] Validation loss: 0.695
# [Epoch: 158 / 200, Iter:    45 / 188] Training loss: 0.515
# [Epoch: 158 / 200, Iter:    90 / 188] Training loss: 0.524
# [Epoch: 158 / 200, Iter:   135 / 188] Training loss: 0.530
# [Epoch: 158 / 200, Iter:   180 / 188] Training loss: 0.538
# [Epoch: 158 / 200] Validation loss: 0.675
# [Epoch: 159 / 200, Iter:    45 / 188] Training loss: 0.534
# [Epoch: 159 / 200, Iter:    90 / 188] Training loss: 0.522
# [Epoch: 159 / 200, Iter:   135 / 188] Training loss: 0.520
# [Epoch: 159 / 200, Iter:   180 / 188] Training loss: 0.536
# [Epoch: 159 / 200] Validation loss: 0.685
# [Epoch: 160 / 200, Iter:    45 / 188] Training loss: 0.535
# [Epoch: 160 / 200, Iter:    90 / 188] Training loss: 0.542
# [Epoch: 160 / 200, Iter:   135 / 188] Training loss: 0.546
# [Epoch: 160 / 200, Iter:   180 / 188] Training loss: 0.543
# [Epoch: 160 / 200] Validation loss: 0.676
# [Epoch: 161 / 200, Iter:    45 / 188] Training loss: 0.533
# [Epoch: 161 / 200, Iter:    90 / 188] Training loss: 0.530
# [Epoch: 161 / 200, Iter:   135 / 188] Training loss: 0.526
# [Epoch: 161 / 200, Iter:   180 / 188] Training loss: 0.532
# [Epoch: 161 / 200] Validation loss: 0.690
# [Epoch: 162 / 200, Iter:    45 / 188] Training loss: 0.538
# [Epoch: 162 / 200, Iter:    90 / 188] Training loss: 0.535
# [Epoch: 162 / 200, Iter:   135 / 188] Training loss: 0.523
# [Epoch: 162 / 200, Iter:   180 / 188] Training loss: 0.526
# [Epoch: 162 / 200] Validation loss: 0.685
# [Epoch: 163 / 200, Iter:    45 / 188] Training loss: 0.487
# [Epoch: 163 / 200, Iter:    90 / 188] Training loss: 0.546
# [Epoch: 163 / 200, Iter:   135 / 188] Training loss: 0.539
# [Epoch: 163 / 200, Iter:   180 / 188] Training loss: 0.549
# [Epoch: 163 / 200] Validation loss: 0.695
# [Epoch: 164 / 200, Iter:    45 / 188] Training loss: 0.541
# [Epoch: 164 / 200, Iter:    90 / 188] Training loss: 0.536
# [Epoch: 164 / 200, Iter:   135 / 188] Training loss: 0.538
# [Epoch: 164 / 200, Iter:   180 / 188] Training loss: 0.536
# [Epoch: 164 / 200] Validation loss: 0.733
# [Epoch: 165 / 200, Iter:    45 / 188] Training loss: 0.539
# [Epoch: 165 / 200, Iter:    90 / 188] Training loss: 0.544
# [Epoch: 165 / 200, Iter:   135 / 188] Training loss: 0.542
# [Epoch: 165 / 200, Iter:   180 / 188] Training loss: 0.541
# [Epoch: 165 / 200] Validation loss: 0.685
# [Epoch: 166 / 200, Iter:    45 / 188] Training loss: 0.535
# [Epoch: 166 / 200, Iter:    90 / 188] Training loss: 0.515
# [Epoch: 166 / 200, Iter:   135 / 188] Training loss: 0.526
# [Epoch: 166 / 200, Iter:   180 / 188] Training loss: 0.538
# [Epoch: 166 / 200] Validation loss: 0.709
# [Epoch: 167 / 200, Iter:    45 / 188] Training loss: 0.516
# [Epoch: 167 / 200, Iter:    90 / 188] Training loss: 0.541
# [Epoch: 167 / 200, Iter:   135 / 188] Training loss: 0.534
# [Epoch: 167 / 200, Iter:   180 / 188] Training loss: 0.533
# [Epoch: 167 / 200] Validation loss: 0.670
# [Epoch: 168 / 200, Iter:    45 / 188] Training loss: 0.491
# [Epoch: 168 / 200, Iter:    90 / 188] Training loss: 0.519
# [Epoch: 168 / 200, Iter:   135 / 188] Training loss: 0.519
# [Epoch: 168 / 200, Iter:   180 / 188] Training loss: 0.513
# [Epoch: 168 / 200] Validation loss: 0.685
# [Epoch: 169 / 200, Iter:    45 / 188] Training loss: 0.494
# [Epoch: 169 / 200, Iter:    90 / 188] Training loss: 0.501
# [Epoch: 169 / 200, Iter:   135 / 188] Training loss: 0.516
# [Epoch: 169 / 200, Iter:   180 / 188] Training loss: 0.512
# [Epoch: 169 / 200] Validation loss: 0.719
# [Epoch: 170 / 200, Iter:    45 / 188] Training loss: 0.522
# [Epoch: 170 / 200, Iter:    90 / 188] Training loss: 0.530
# [Epoch: 170 / 200, Iter:   135 / 188] Training loss: 0.535
# [Epoch: 170 / 200, Iter:   180 / 188] Training loss: 0.537
# [Epoch: 170 / 200] Validation loss: 0.651
# [Epoch: 171 / 200, Iter:    45 / 188] Training loss: 0.535
# [Epoch: 171 / 200, Iter:    90 / 188] Training loss: 0.521
# [Epoch: 171 / 200, Iter:   135 / 188] Training loss: 0.534
# [Epoch: 171 / 200, Iter:   180 / 188] Training loss: 0.531
# [Epoch: 171 / 200] Validation loss: 0.696
# [Epoch: 172 / 200, Iter:    45 / 188] Training loss: 0.501
# [Epoch: 172 / 200, Iter:    90 / 188] Training loss: 0.508
# [Epoch: 172 / 200, Iter:   135 / 188] Training loss: 0.528
# [Epoch: 172 / 200, Iter:   180 / 188] Training loss: 0.532
# [Epoch: 172 / 200] Validation loss: 0.672
# [Epoch: 173 / 200, Iter:    45 / 188] Training loss: 0.526
# [Epoch: 173 / 200, Iter:    90 / 188] Training loss: 0.537
# [Epoch: 173 / 200, Iter:   135 / 188] Training loss: 0.529
# [Epoch: 173 / 200, Iter:   180 / 188] Training loss: 0.529
# [Epoch: 173 / 200] Validation loss: 0.701
# [Epoch: 174 / 200, Iter:    45 / 188] Training loss: 0.559
# [Epoch: 174 / 200, Iter:    90 / 188] Training loss: 0.535
# [Epoch: 174 / 200, Iter:   135 / 188] Training loss: 0.540
# [Epoch: 174 / 200, Iter:   180 / 188] Training loss: 0.534
# [Epoch: 174 / 200] Validation loss: 0.674
# [Epoch: 175 / 200, Iter:    45 / 188] Training loss: 0.505
# [Epoch: 175 / 200, Iter:    90 / 188] Training loss: 0.507
# [Epoch: 175 / 200, Iter:   135 / 188] Training loss: 0.519
# [Epoch: 175 / 200, Iter:   180 / 188] Training loss: 0.532
# [Epoch: 175 / 200] Validation loss: 0.677
# [Epoch: 176 / 200, Iter:    45 / 188] Training loss: 0.513
# [Epoch: 176 / 200, Iter:    90 / 188] Training loss: 0.519
# [Epoch: 176 / 200, Iter:   135 / 188] Training loss: 0.518
# [Epoch: 176 / 200, Iter:   180 / 188] Training loss: 0.524
# [Epoch: 176 / 200] Validation loss: 0.657
# [Epoch: 177 / 200, Iter:    45 / 188] Training loss: 0.515
# [Epoch: 177 / 200, Iter:    90 / 188] Training loss: 0.500
# [Epoch: 177 / 200, Iter:   135 / 188] Training loss: 0.502
# [Epoch: 177 / 200, Iter:   180 / 188] Training loss: 0.514
# [Epoch: 177 / 200] Validation loss: 0.687
# [Epoch: 178 / 200, Iter:    45 / 188] Training loss: 0.509
# [Epoch: 178 / 200, Iter:    90 / 188] Training loss: 0.508
# [Epoch: 178 / 200, Iter:   135 / 188] Training loss: 0.513
# [Epoch: 178 / 200, Iter:   180 / 188] Training loss: 0.508
# [Epoch: 178 / 200] Validation loss: 0.670
# [Epoch: 179 / 200, Iter:    45 / 188] Training loss: 0.498
# [Epoch: 179 / 200, Iter:    90 / 188] Training loss: 0.503
# [Epoch: 179 / 200, Iter:   135 / 188] Training loss: 0.490
# [Epoch: 179 / 200, Iter:   180 / 188] Training loss: 0.512
# [Epoch: 179 / 200] Validation loss: 0.695
# [Epoch: 180 / 200, Iter:    45 / 188] Training loss: 0.493
# [Epoch: 180 / 200, Iter:    90 / 188] Training loss: 0.507
# [Epoch: 180 / 200, Iter:   135 / 188] Training loss: 0.508
# [Epoch: 180 / 200, Iter:   180 / 188] Training loss: 0.509
# [Epoch: 180 / 200] Validation loss: 0.692
# [Epoch: 181 / 200, Iter:    45 / 188] Training loss: 0.508
# [Epoch: 181 / 200, Iter:    90 / 188] Training loss: 0.538
# [Epoch: 181 / 200, Iter:   135 / 188] Training loss: 0.533
# [Epoch: 181 / 200, Iter:   180 / 188] Training loss: 0.526
# [Epoch: 181 / 200] Validation loss: 0.678
# [Epoch: 182 / 200, Iter:    45 / 188] Training loss: 0.490
# [Epoch: 182 / 200, Iter:    90 / 188] Training loss: 0.499
# [Epoch: 182 / 200, Iter:   135 / 188] Training loss: 0.508
# [Epoch: 182 / 200, Iter:   180 / 188] Training loss: 0.510
# [Epoch: 182 / 200] Validation loss: 0.681
# [Epoch: 183 / 200, Iter:    45 / 188] Training loss: 0.462
# [Epoch: 183 / 200, Iter:    90 / 188] Training loss: 0.487
# [Epoch: 183 / 200, Iter:   135 / 188] Training loss: 0.499
# [Epoch: 183 / 200, Iter:   180 / 188] Training loss: 0.506
# [Epoch: 183 / 200] Validation loss: 0.693
# [Epoch: 184 / 200, Iter:    45 / 188] Training loss: 0.516
# [Epoch: 184 / 200, Iter:    90 / 188] Training loss: 0.507
# [Epoch: 184 / 200, Iter:   135 / 188] Training loss: 0.504
# [Epoch: 184 / 200, Iter:   180 / 188] Training loss: 0.502
# [Epoch: 184 / 200] Validation loss: 0.749
# [Epoch: 185 / 200, Iter:    45 / 188] Training loss: 0.518
# [Epoch: 185 / 200, Iter:    90 / 188] Training loss: 0.514
# [Epoch: 185 / 200, Iter:   135 / 188] Training loss: 0.510
# [Epoch: 185 / 200, Iter:   180 / 188] Training loss: 0.519
# [Epoch: 185 / 200] Validation loss: 0.654
# [Epoch: 186 / 200, Iter:    45 / 188] Training loss: 0.520
# [Epoch: 186 / 200, Iter:    90 / 188] Training loss: 0.507
# [Epoch: 186 / 200, Iter:   135 / 188] Training loss: 0.515
# [Epoch: 186 / 200, Iter:   180 / 188] Training loss: 0.506
# [Epoch: 186 / 200] Validation loss: 0.677
# [Epoch: 187 / 200, Iter:    45 / 188] Training loss: 0.487
# [Epoch: 187 / 200, Iter:    90 / 188] Training loss: 0.487
# [Epoch: 187 / 200, Iter:   135 / 188] Training loss: 0.510
# [Epoch: 187 / 200, Iter:   180 / 188] Training loss: 0.503
# [Epoch: 187 / 200] Validation loss: 0.707
# [Epoch: 188 / 200, Iter:    45 / 188] Training loss: 0.485
# [Epoch: 188 / 200, Iter:    90 / 188] Training loss: 0.501
# [Epoch: 188 / 200, Iter:   135 / 188] Training loss: 0.501
# [Epoch: 188 / 200, Iter:   180 / 188] Training loss: 0.502
# [Epoch: 188 / 200] Validation loss: 0.681
# [Epoch: 189 / 200, Iter:    45 / 188] Training loss: 0.477
# [Epoch: 189 / 200, Iter:    90 / 188] Training loss: 0.494
# [Epoch: 189 / 200, Iter:   135 / 188] Training loss: 0.507
# [Epoch: 189 / 200, Iter:   180 / 188] Training loss: 0.504
# [Epoch: 189 / 200] Validation loss: 0.673
# [Epoch: 190 / 200, Iter:    45 / 188] Training loss: 0.480
# [Epoch: 190 / 200, Iter:    90 / 188] Training loss: 0.490
# [Epoch: 190 / 200, Iter:   135 / 188] Training loss: 0.496
# [Epoch: 190 / 200, Iter:   180 / 188] Training loss: 0.499
# [Epoch: 190 / 200] Validation loss: 0.689
# [Epoch: 191 / 200, Iter:    45 / 188] Training loss: 0.482
# [Epoch: 191 / 200, Iter:    90 / 188] Training loss: 0.491
# [Epoch: 191 / 200, Iter:   135 / 188] Training loss: 0.499
# [Epoch: 191 / 200, Iter:   180 / 188] Training loss: 0.498
# [Epoch: 191 / 200] Validation loss: 0.725
# [Epoch: 192 / 200, Iter:    45 / 188] Training loss: 0.447
# [Epoch: 192 / 200, Iter:    90 / 188] Training loss: 0.462
# [Epoch: 192 / 200, Iter:   135 / 188] Training loss: 0.494
# [Epoch: 192 / 200, Iter:   180 / 188] Training loss: 0.498
# [Epoch: 192 / 200] Validation loss: 0.666
# [Epoch: 193 / 200, Iter:    45 / 188] Training loss: 0.498
# [Epoch: 193 / 200, Iter:    90 / 188] Training loss: 0.496
# [Epoch: 193 / 200, Iter:   135 / 188] Training loss: 0.488
# [Epoch: 193 / 200, Iter:   180 / 188] Training loss: 0.498
# [Epoch: 193 / 200] Validation loss: 0.681
# [Epoch: 194 / 200, Iter:    45 / 188] Training loss: 0.500
# [Epoch: 194 / 200, Iter:    90 / 188] Training loss: 0.482
# [Epoch: 194 / 200, Iter:   135 / 188] Training loss: 0.493
# [Epoch: 194 / 200, Iter:   180 / 188] Training loss: 0.497
# [Epoch: 194 / 200] Validation loss: 0.657
# [Epoch: 195 / 200, Iter:    45 / 188] Training loss: 0.505
# [Epoch: 195 / 200, Iter:    90 / 188] Training loss: 0.515
# [Epoch: 195 / 200, Iter:   135 / 188] Training loss: 0.511
# [Epoch: 195 / 200, Iter:   180 / 188] Training loss: 0.495
# [Epoch: 195 / 200] Validation loss: 0.703
# [Epoch: 196 / 200, Iter:    45 / 188] Training loss: 0.442
# [Epoch: 196 / 200, Iter:    90 / 188] Training loss: 0.466
# [Epoch: 196 / 200, Iter:   135 / 188] Training loss: 0.482
# [Epoch: 196 / 200, Iter:   180 / 188] Training loss: 0.483
# [Epoch: 196 / 200] Validation loss: 0.669
# [Epoch: 197 / 200, Iter:    45 / 188] Training loss: 0.468
# [Epoch: 197 / 200, Iter:    90 / 188] Training loss: 0.500
# [Epoch: 197 / 200, Iter:   135 / 188] Training loss: 0.504
# [Epoch: 197 / 200, Iter:   180 / 188] Training loss: 0.507
# [Epoch: 197 / 200] Validation loss: 0.665
# [Epoch: 198 / 200, Iter:    45 / 188] Training loss: 0.480
# [Epoch: 198 / 200, Iter:    90 / 188] Training loss: 0.480
# [Epoch: 198 / 200, Iter:   135 / 188] Training loss: 0.488
# [Epoch: 198 / 200, Iter:   180 / 188] Training loss: 0.489
# [Epoch: 198 / 200] Validation loss: 0.663
# [Epoch: 199 / 200, Iter:    45 / 188] Training loss: 0.464
# [Epoch: 199 / 200, Iter:    90 / 188] Training loss: 0.481
# [Epoch: 199 / 200, Iter:   135 / 188] Training loss: 0.485
# [Epoch: 199 / 200, Iter:   180 / 188] Training loss: 0.489
# [Epoch: 199 / 200] Validation loss: 0.676
# [Epoch: 200 / 200, Iter:    45 / 188] Training loss: 0.495
# [Epoch: 200 / 200, Iter:    90 / 188] Training loss: 0.497
# [Epoch: 200 / 200, Iter:   135 / 188] Training loss: 0.496
# [Epoch: 200 / 200, Iter:   180 / 188] Training loss: 0.501
# [Epoch: 200 / 200] Validation loss: 0.681
# Finished Training

# %% [markdown]
# ## Step 5: Test the Network
#
# After training the network, it is time to test our network on the validation set, which includes images not seen during training. This will tell us how well the network can perform on new data.
#
# We first visualize several network predictions on validation samples along with the ground truth labels.
# You can run this cell multiple times to visualize different images.

# %%
# get a few validation samples
images, labels = next(iter(val_loader))

# get network output

# Set network to eval mode before validation
cnn_network.eval()
outputs = cnn_network(images)  # classification scores
_, predicted = torch.max(outputs, 1)  # use maximum as prediction label

# visualize ground truth and predictions
show_images(images[:4], labels[:4], predicted[:4])

# %% [markdown]
# To get the full picture of the network performance, we need to evaluate on the full validation set.
# This cell will iterate over every validation image, obtain the network prediction, and compare with the corresponding ground truth.
# The evaluation score is the percentage of labels predicted correctly.
# This may take some time.
# You should see an accuracy of around 63%.

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs

# Set network to eval mode before validation
cnn_network.eval()

with torch.no_grad():
    for i, data in enumerate(val_loader):
        images, labels = data
        # calculate outputs by running images through the network
        outputs = cnn_network(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        if (i + 1) % 50 == 0:
            print(f'Validation [{i + 1:5d} / {len(val_loader)}]')

print(f'Accuracy of the network on the 1500 validation images: {100 * correct / total:.2f} %')
# Out:
# Accuracy of the network on the 1500 validation images: 75.08 %

# %% [markdown]
# ## Your Turn
#
# **TODO:** We provided a simple CNN and boilerplate training code to introduce PyTorch to you.
# These are written in their simplest form to leave ample room for extension.
# Your task is to improve the network's performance on the test set.
#
# **Note:** You are not allowed to use any external packages except the ones already imported in `cnn_network.py`. Otherwise your submission will crash on the Evaluation server.
#
#
# **Hints:** Things that can potentially improve test accuracy:
# - Deeper architecture: Adding more layers can lead to better performance, but be careful of overfitting to the training set!
# - Activation functions: Introducing activation functions can increase the capacity of the network.
# - Training parameters: Modifying the length of training, learning rate, optimizer, loss function, etc. can all improve network performance, but again be careful of overfitting!
# - Transforms: Adding data transforms essentially generates more data for training, which helps alleviate overfitting. See full list of available transforms [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ## Generate the final submission on the test set
#
# When you are happy with your network, you can run the next cell to generate your network predictions on the test set, which will be stored in the submission directory on your Google Drive.
# Download the submission folder (**without renaming**) as a zip, and upload it to the evaluation server at https://codalab.lisn.upsaclay.fr/competitions/8751 to obtain the scores on the test set.

# %%
predictions = []

# Set network to eval mode before testing
cnn_network.eval()

with torch.no_grad():
    for i, data in enumerate(test_loader):
        images = data
        # calculate outputs by running images through the network
        outputs = cnn_network(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        predictions.append(predicted.item())

        if (i + 1) % 100 == 0:
            print(f'Test [{i + 1:5d} / {len(test_loader)}]')

print("Writing predictions to file..")
test_imgs = []
with open(f"{env_path}/data/test.csv", "r") as f:
    reader = csv.reader(f, delimiter="\t")
    for i, line in enumerate(reader):
        test_imgs.append(line[0])

out_dir = f'{env_path}/submission'
os.makedirs(out_dir, exist_ok=True)
with open(f'{out_dir}/test.csv', 'w') as fp:
    writer = csv.writer(fp)
    for test_img, pred in zip(test_imgs, predictions):
        writer.writerow([test_img, str(pred)])
shutil.copyfile(f'{env_path}/cnn_network.py', f'{out_dir}/cnn_network.py')
print("Done. You can submit now.")
# Out:
# Test [  100 / 1200]
# Test [  200 / 1200]
# Test [  300 / 1200]
# Test [  400 / 1200]
# Test [  500 / 1200]
# Test [  600 / 1200]
# Test [  700 / 1200]
# Test [  800 / 1200]
# Test [  900 / 1200]
# Test [ 1000 / 1200]
# Test [ 1100 / 1200]
# Test [ 1200 / 1200]
# Writing predictions to file..
# Done. You can submit now.
